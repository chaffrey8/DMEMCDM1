# %% [markdown]
# # Estructuras de datos

# %% [markdown]
# ## Listas (vectores)

# %% [markdown]
# 1. "Mutables"
# 2. Indexados (Orden)
#
# [] sirve para declarar una lista de inicio
#
# list() sirve para transformar otra estructura en una lista

# %%
x = ['banana','manzana','naranja','fresa']

# %%
x
# Out:
# ['banana', 'manzana', 'naranja', 'fresa']

# %%
y = list(('banana','manzana','naranja','fresa'))

# %%
y
# Out:
# ['banana', 'manzana', 'naranja', 'fresa']

# %% [markdown]
# ### Operaciones

# %% [markdown]
# 1. "Suma"

# %%
[3,5,6] + [7,8,9]
# Out:
# [3, 5, 6, 7, 8, 9]

# %% [markdown]
# 2. "Resta"

# %%
[3,5,6] - [7,8,9]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 [3,5,6] - [7,8,9]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %% [markdown]
# 3. "Multiplicación"

# %%
[3,5,6] * 5
# Out:
# [3, 5, 6, 3, 5, 6, 3, 5, 6, 3, 5, 6, 3, 5, 6]

# %% [markdown]
# 4. "División"

# %%
[3,5,6] / 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 [3,5,6] / 2
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %% [markdown]
# ### Acceder a elementos

# %%
x[1]
# Out:
# 'manzana'

# %% [markdown]
# inicio:final(no incluído):tamaño_de_paso
#
# Valores default:
# 1. inicio = 0
# 2. final = -1
# 3. tama_de_paso = 1

# %%
x[0:4:3]
# Out:
# ['banana', 'fresa']

# %%
x[1:4]
# Out:
# ['manzana', 'naranja', 'fresa']

# %%
x[:2]
# Out:
# ['banana', 'manzana']

# %%
x[2:]
# Out:
# ['naranja', 'fresa']

# %%
x[-1]
# Out:
# 'fresa'

# %%
x[-2]
# Out:
# 'naranja'

# %% [markdown]
# ### Modificar elementos

# %%
x[1] = 'pera'

# %%
x
# Out:
# ['banana', 'pera', 'naranja', 'fresa']

# %%
x[0:4:3] = ['papaya','sandia']

# %%
x
# Out:
# ['papaya', 'pera', 'naranja', 'sandia']

# %%
x[:2] = ['banana','manzana']

# %%
x
# Out:
# ['banana', 'manzana', 'naranja', 'sandia']

# %%
x[-1] = 'fresa'

# %%
x
# Out:
# ['banana', 'manzana', 'naranja', 'fresa']

# %% [markdown]
# ### Agregar elementos

# %%
for ix,valor in enumerate(x):
    print(f'{ix}\t{valor}')
# Out:
# 0	banana
# 1	manzana
# 2	naranja
# 3	fresa

# %% [markdown]
# help()
#
# dir()

# %%
dir(x)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
x + ['mango']
# Out:
# ['banana', 'manzana', 'naranja', 'fresa', 'mango']

# %%
x.append('mango')

# %%
x
# Out:
# ['banana', 'manzana', 'naranja', 'fresa', 'mango']

# %%
x[:3] + ['sandia'] + x[3:]
# Out:
# ['banana', 'manzana', 'naranja', 'sandia', 'fresa', 'mango']

# %%
x.insert(3,'sandia')

# %%
x
# Out:
# ['banana', 'manzana', 'naranja', 'sandia', 'fresa', 'mango']

# %%
x + ['papaya','maracuya']
# Out:
# ['banana',
#  'manzana',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %%
x.extend(['papaya','maracuya'])

# %%
x
# Out:
# ['banana',
#  'manzana',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %% [markdown]
# ### Remover elementos

# %%
resultado = x.remove('banana')

# %%
x
# Out:
# ['manzana', 'naranja', 'sandia', 'fresa', 'mango', 'papaya', 'maracuya']

# %%
resultado

# %%
x.remove('banana')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 x.remove('banana')
#
# ValueError: list.remove(x): x not in list

# %%
resultado = x.pop()

# %%
x
# Out:
# ['manzana', 'naranja', 'sandia', 'fresa', 'mango', 'papaya']

# %%
resultado
# Out:
# 'maracuya'

# %%
x.pop(2)
# Out:
# 'sandia'

# %%
x
# Out:
# ['manzana', 'naranja', 'fresa', 'mango', 'papaya']

# %% [markdown]
# ### Iterar en elementos

# %%
for fruta in x:
    print(fruta)
# Out:
# manzana
# naranja
# fresa
# mango
# papaya

# %%
for ix in range(len(x)):
    print(x[ix])
# Out:
# manzana
# naranja
# fresa
# mango
# papaya

# %%
for ix,fruta in enumerate(x):
    print(f'{ix}\t{fruta}')
# Out:
# 0	manzana
# 1	naranja
# 2	fresa
# 3	mango
# 4	papaya

# %%
while x:
    x.pop()

# %%
x
# Out:
# []

# %% [markdown]
# ### List comprehension

# %%
x = ['bananana','manzana', 'naranja', 'sandia', 'fresa', 'mango', 'papaya', 'maracuya']

# %%
x_modificado = ['bananana_modificada','manzana_modificada', 'naranja_modificada', 'sandia_modificada', 'fresa_modificada', 'mango_modificada', 'papaya_modificada', 'maracuya_modificada']

# %%
x_modificado
# Out:
# ['bananana',
#  'manzana',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %%
x_modificado = x

# %%
x_modificado
# Out:
# ['bananana',
#  'manzana',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %%
x
# Out:
# ['bananana',
#  'manzana',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %%
x[1] = 'manzana_verde'

# %%
x
# Out:
# ['bananana',
#  'manzana_verde',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %%
x_modificado
# Out:
# ['bananana',
#  'manzana_verde',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %%
x_modificado_2 = x.copy()

# %%
x_modificado_2
# Out:
# ['bananana',
#  'manzana_verde',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %%
x[1] = 'manzana'

# %%
x
# Out:
# ['bananana',
#  'manzana',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %%
x_modificado
# Out:
# ['bananana',
#  'manzana',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %%
x_modificado_2
# Out:
# ['bananana',
#  'manzana_verde',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %%
x_modificado_2
# Out:
# ['bananana',
#  'manzana_verde',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %%
for ix,_ in enumerate(x_modificado_2):
    x_modificado_2[ix] += '_modificado'

# %%
x_modificado_2
# Out:
# ['bananana_modificado',
#  'manzana_verde_modificado',
#  'naranja_modificado',
#  'sandia_modificado',
#  'fresa_modificado',
#  'mango_modificado',
#  'papaya_modificado',
#  'maracuya_modificado']

# %%
x_modificado_3 = [fruta + '_modificado' for fruta in x]

# %%
x_modificado_3
# Out:
# ['bananana_modificado',
#  'manzana_modificado',
#  'naranja_modificado',
#  'sandia_modificado',
#  'fresa_modificado',
#  'mango_modificado',
#  'papaya_modificado',
#  'maracuya_modificado']

# %%
x_original = [fruta for ix,fruta in enumerate(x) if ix%2==0]

# %%
x_original
# Out:
# ['bananana', 'naranja', 'fresa', 'papaya']

# %%
x
# Out:
# ['bananana',
#  'manzana',
#  'naranja',
#  'sandia',
#  'fresa',
#  'mango',
#  'papaya',
#  'maracuya']

# %% [markdown]
# ### Ordenamiento

# %%
x.sort()

# %%
x
# Out:
# ['bananana',
#  'fresa',
#  'mango',
#  'manzana',
#  'maracuya',
#  'naranja',
#  'papaya',
#  'sandia']

# %%
x.sort(reverse=True)

# %%
x
# Out:
# ['sandia',
#  'papaya',
#  'naranja',
#  'maracuya',
#  'manzana',
#  'mango',
#  'fresa',
#  'bananana']

# %%
x.sort(key=lambda fruta: fruta[2:3])

# %%
x
# Out:
# ['fresa',
#  'sandia',
#  'manzana',
#  'mango',
#  'bananana',
#  'papaya',
#  'naranja',
#  'maracuya']

# %%
'fresa'[2:3]
# Out:
# 'e'

# %%
matriz = [[1,2,3],[4,5,6],[7,8,9]]

# %%
matriz
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matriz[0][2]
# Out:
# 3

# %% [markdown]
# ## Tuplas

# %% [markdown]
# 1. "Inmutables"
# 2. Orden
#
# ()
#
# tuple()

# %%
x = ('banana','manzana','naranja','fresa')

# %%
x[0]
# Out:
# 'banana'

# %%
x[2:4]
# Out:
# ('naranja', 'fresa')

# %%
x[0] = 'no banana'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 x[0] = 'no banana'
#
# TypeError: 'tuple' object does not support item assignment

# %%
x.count('naranja')
# Out:
# 1

# %%
x.count('pera')
# Out:
# 0

# %%
x.index('naranja')
# Out:
# 2

# %%
x.index('pera')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 x.index('pera')
#
# ValueError: tuple.index(x): x not in tuple

# %%
x = ('banana','banana','pera','banana','manzana')

# %%
x.index('banana')
# Out:
# 0

# %%
indices = [ix for ix,fruta in enumerate(x) if fruta == 'banana']

# %%
indices
# Out:
# [0, 1, 3]

# %% [markdown]
# ## Conjuntos

# %% [markdown]
# 1. No ordenados
# 2. "Mutables"
# 3. No se repiten elementos
#
# {}
#
# set()

# %%
x = {'banana','manzana','naranja','fresa','maracuya','manzana'}

# %%
x
# Out:
# {'banana', 'fresa', 'manzana', 'maracuya', 'naranja'}

# %%
for fruta in x:
    print(fruta)
# Out:
# banana
# manzana
# naranja
# fresa
# maracuya

# %%
'banana' in x
# Out:
# True

# %%
'pera' in x
# Out:
# False

# %%
dir(x)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
x = {'banana','manzana','fresa'}
y = {'banana','piña','maracuya','sandia'}

# %%
x.union(y)
# Out:
# {'banana', 'fresa', 'manzana', 'maracuya', 'piña', 'sandia'}

# %%
x.difference(y)
# Out:
# {'fresa', 'manzana'}

# %%
x.symmetric_difference(y)
# Out:
# {'fresa', 'manzana', 'maracuya', 'piña', 'sandia'}

# %% [markdown]
# ## Diccionario

# %% [markdown]
# 1. "Mutables"
# 2. No repiten elementos
# 3. "Ordenados"
#
# {:}
#
# dict()

# %%
x = {'frutas':['banana','manzana','pera','sandia'],'colores':['amarillo','azul','verde']}

# %%
x
# Out:
# {'frutas': ['banana', 'manzana', 'pera', 'sandia'],
#  'colores': ['amarillo', 'azul', 'verde']}

# %%
x.keys()
# Out:
# dict_keys(['frutas', 'colores'])

# %%
x['frutas']
# Out:
# ['banana', 'manzana', 'pera', 'sandia']

# %%
x['colores']
# Out:
# ['amarillo', 'azul', 'verde']

# %%
x[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 x[0]
#
# KeyError: 0

# %%
x.values()
# Out:
# dict_values([['banana', 'manzana', 'pera', 'sandia'], ['amarillo', 'azul', 'verde']])

# %%
x.items()
# Out:
# dict_items([('frutas', ['banana', 'manzana', 'pera', 'sandia']), ('colores', ['amarillo', 'azul', 'verde'])])

# %%
x[0] = 42

# %%
x
# Out:
# {'frutas': ['banana', 'manzana', 'pera', 'sandia'],
#  'colores': ['amarillo', 'azul', 'verde'],
#  0: 42}

# %%
x.get(1,'no esta')
# Out:
# 'no esta'

# %%
x.get(0,'no esta')
# Out:
# 42

# %%
json = {'valores':{'pantalla':35,'largo':23},'otro':{'frutas':['manzana'],'colores':['amarillo']}}

# %%
json
# Out:
# {'valores': {'pantalla': 35, 'largo': 23},
#  'otro': {'frutas': ['manzana'], 'colores': ['amarillo']}}

# %%
dir(json)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
3/2
# Out:
# 1.5

# %%
3//2
# Out:
# 1

# %%
int(3/2)
# Out:
# 1
